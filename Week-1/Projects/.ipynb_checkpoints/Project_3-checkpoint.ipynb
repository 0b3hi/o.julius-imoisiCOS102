# %% [markdown]
# ![image.png](attachment:f23ee575-86df-4869-ba9b-0e5a25f66ac7.png)

# %%
P = int(input("Enter P: "))
R = int(input("Enter R: "))
T = int(input("Enter T: "))
M = int(input("Enter M: "))
n = int(input("Enter n: "))
x = int(input("Enter x: "))

AP = P * M * T * x * ((1 + R / n ) ** (n * T) - 1) / (R / n)
print("The Annuity Plan is: ", AP)
# Out:
# Enter P:  10
# Enter R:  3
# Enter T:  2
# Enter M:  4
# Enter n:  5
# Enter x:  6
# The Annuity Plan is:  87160.93022208005
