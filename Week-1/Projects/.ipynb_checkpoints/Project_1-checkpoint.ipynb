# %% [markdown]
# ![image.png](attachment:99fe5b2e-6925-4539-a0e1-a18f8b1d6b63.png)

# %%
P = int(input("Enter the Principal: "))
R = int(input("Enter the Rate: "))
T = int(input("Enter the Time: "))

A = P * (1 + (R / 100 ) * T)
print("The simple interest is:", A)
# Out:
# Enter the Principal:  10
# Enter the Rate:  6
# Enter the Time:  4
# The simple interest is: 12.4
