# %% [markdown]
# ![image.png](attachment:88f96814-278f-4062-baec-fdd96dd653f7.png)

# %%
P = int(input("Enter P: "))
R = int(input("Enter R: "))
T = int(input("Enter T: "))
n = int(input("Enter n: "))

CI = P * (1 + R / n) ** (n * T)
print("The Compound interest is: ", CI)
# Out:
# Enter P:  10
# Enter R:  9
# Enter T:  4
# Enter n:  5
# The Compound interest is:  8773252460.082333
