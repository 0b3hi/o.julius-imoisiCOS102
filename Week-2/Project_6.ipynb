# %%
print("IZIFIN TECHNOLOGY")
Years = int(input("How many years of work experience do you have?"))
Age = int(input("How old are you?"))

if Years > 25 and Age >= 55:
    print("Your Total Annual Tax Revenue is ₦5,600,000")
elif Years > 20 and Age >= 45:
    print("Your Total Annual Tax Revenue is ₦4,480,000")
elif Years > 10 and Age >= 35:
    print("Your Total Annual Tax Revenue is ₦1,500,000")
else:
    print("Your Total Annual Tax Revenue is ₦550,000")
# Out:
# IZIFIN TECHNOLOGY
# How many years of work experience do you have? 25
# How old are you? 59
# Your Total Annual Tax Revenue is ₦4,480,000
